# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %pwd
# %cd "gdrive/My Drive/D_For_Data_Scientist/Computer Vision/temp/Day42"
# %pwd
# Out:
# /content/gdrive/My Drive/D_For_Data_Scientist/Computer Vision/temp/Day42
# '/content/gdrive/My Drive/D_For_Data_Scientist/Computer Vision/temp/Day42'

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0056 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00202, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00202 to 0.00191, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 0.0011 - val_loss: 0.0020
#
# Epoch 00004: val_loss did not improve from 0.00188
# Epoch 5/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00185, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 9.4509e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00185 to 0.00169, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 8.1951e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00169 to 0.00159, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 305us/step - loss: 7.0417e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00159 to 0.00142, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 288us/step - loss: 6.0716e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00142 to 0.00132, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 5.5324e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00132 to 0.00122, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 4.8670e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00122 to 0.00107, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 4.4667e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00107 to 0.00103, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 4.1479e-04 - val_loss: 9.8726e-04
#
# Epoch 00013: val_loss improved from 0.00103 to 0.00099, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 3.9178e-04 - val_loss: 9.6237e-04
#
# Epoch 00014: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 301us/step - loss: 3.7776e-04 - val_loss: 0.0010
#
# Epoch 00015: val_loss did not improve from 0.00096
# Epoch 16/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 3.5894e-04 - val_loss: 9.3289e-04
#
# Epoch 00016: val_loss improved from 0.00096 to 0.00093, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 3.3346e-04 - val_loss: 9.0970e-04
#
# Epoch 00017: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 3.2815e-04 - val_loss: 9.0852e-04
#
# Epoch 00018: val_loss improved from 0.00091 to 0.00091, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 301us/step - loss: 3.1102e-04 - val_loss: 9.0894e-04
#
# Epoch 00019: val_loss did not improve from 0.00091
# Epoch 20/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 3.0461e-04 - val_loss: 8.4486e-04
#
# Epoch 00020: val_loss improved from 0.00091 to 0.00084, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 305us/step - loss: 2.8459e-04 - val_loss: 8.3538e-04
#
# Epoch 00021: val_loss improved from 0.00084 to 0.00084, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 2.8200e-04 - val_loss: 8.5655e-04
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/150
# 1712/1712 [==============================] - 1s 304us/step - loss: 2.7618e-04 - val_loss: 8.4011e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 2.6643e-04 - val_loss: 8.6065e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 2.5993e-04 - val_loss: 8.8231e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 2.5419e-04 - val_loss: 8.0835e-04
#
# Epoch 00026: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 2.4691e-04 - val_loss: 8.1501e-04
#
# Epoch 00027: val_loss did not improve from 0.00081
# Epoch 28/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 2.5080e-04 - val_loss: 8.0230e-04
#
# Epoch 00028: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 2.3864e-04 - val_loss: 8.1696e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 2.3162e-04 - val_loss: 8.1495e-04
#
# Epoch 00030: val_loss did not improve from 0.00080
# Epoch 31/150
# 1712/1712 [==============================] - 1s 304us/step - loss: 2.2453e-04 - val_loss: 8.0327e-04
#
# Epoch 00031: val_loss did not improve from 0.00080
# Epoch 32/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 2.2394e-04 - val_loss: 7.9996e-04
#
# Epoch 00032: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 2.2411e-04 - val_loss: 8.0868e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 2.1951e-04 - val_loss: 8.8063e-04
#
# Epoch 00034: val_loss did not improve from 0.00080
# Epoch 35/150
# 1712/1712 [==============================] - 0s 288us/step - loss: 2.0713e-04 - val_loss: 8.2091e-04
#
# Epoch 00035: val_loss did not improve from 0.00080
# Epoch 36/150
# 1712/1712 [==============================] - 1s 292us/step - loss: 2.1215e-04 - val_loss: 8.2268e-04
#
# Epoch 00036: val_loss did not improve from 0.00080
# Epoch 37/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 2.0096e-04 - val_loss: 7.9366e-04
#
# Epoch 00037: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 1.9867e-04 - val_loss: 8.1077e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.9740e-04 - val_loss: 8.0472e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.9780e-04 - val_loss: 7.8451e-04
#
# Epoch 00040: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.8716e-04 - val_loss: 8.0461e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 1s 292us/step - loss: 1.9346e-04 - val_loss: 8.1432e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 2.0676e-04 - val_loss: 7.7972e-04
#
# Epoch 00043: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.8517e-04 - val_loss: 7.8735e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.8038e-04 - val_loss: 7.9088e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 1.7730e-04 - val_loss: 7.9538e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 1.7302e-04 - val_loss: 7.8106e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.7785e-04 - val_loss: 8.2023e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 1.8722e-04 - val_loss: 7.8816e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.7759e-04 - val_loss: 7.9661e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.6813e-04 - val_loss: 7.7068e-04
#
# Epoch 00051: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.7484e-04 - val_loss: 8.3020e-04
#
# Epoch 00052: val_loss did not improve from 0.00077
# Epoch 53/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.6680e-04 - val_loss: 7.8133e-04
#
# Epoch 00053: val_loss did not improve from 0.00077
# Epoch 54/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.5815e-04 - val_loss: 8.3970e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.6361e-04 - val_loss: 7.6284e-04
#
# Epoch 00055: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.5938e-04 - val_loss: 7.9510e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 1.6160e-04 - val_loss: 7.6604e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 1.5687e-04 - val_loss: 7.7543e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 1.5497e-04 - val_loss: 7.7051e-04
#
# Epoch 00059: val_loss did not improve from 0.00076
# Epoch 60/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.5344e-04 - val_loss: 7.8634e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.5469e-04 - val_loss: 7.7559e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 1.4969e-04 - val_loss: 7.6767e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 1.5188e-04 - val_loss: 7.7044e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 1.4714e-04 - val_loss: 8.0500e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 1.4635e-04 - val_loss: 7.5695e-04
#
# Epoch 00065: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.4280e-04 - val_loss: 7.8742e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.4182e-04 - val_loss: 8.0582e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.4401e-04 - val_loss: 7.6415e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.4006e-04 - val_loss: 7.7320e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.3557e-04 - val_loss: 8.3512e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 0s 290us/step - loss: 1.3573e-04 - val_loss: 7.6216e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 0s 288us/step - loss: 1.3682e-04 - val_loss: 7.9279e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.3387e-04 - val_loss: 8.1083e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 1.3725e-04 - val_loss: 8.2117e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.3479e-04 - val_loss: 8.0696e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.3248e-04 - val_loss: 7.7991e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.2737e-04 - val_loss: 8.1192e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 1s 308us/step - loss: 1.2582e-04 - val_loss: 7.9454e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 1.2616e-04 - val_loss: 7.6083e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.2253e-04 - val_loss: 8.0444e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.2200e-04 - val_loss: 7.7045e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.2654e-04 - val_loss: 7.7160e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 1.2215e-04 - val_loss: 8.1593e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 1s 308us/step - loss: 1.2755e-04 - val_loss: 8.2143e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.2222e-04 - val_loss: 8.5256e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 1.2135e-04 - val_loss: 7.9203e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 0s 288us/step - loss: 1.1960e-04 - val_loss: 8.2064e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.1743e-04 - val_loss: 8.1475e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.1658e-04 - val_loss: 7.7735e-04
#
# Epoch 00089: val_loss did not improve from 0.00076
# Epoch 90/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 1.1685e-04 - val_loss: 7.9105e-04
#
# Epoch 00090: val_loss did not improve from 0.00076
# Epoch 91/150
# 1712/1712 [==============================] - 0s 289us/step - loss: 1.1864e-04 - val_loss: 7.7183e-04
#
# Epoch 00091: val_loss did not improve from 0.00076
# Epoch 92/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 1.1668e-04 - val_loss: 8.2531e-04
#
# Epoch 00092: val_loss did not improve from 0.00076
# Epoch 93/150
# 1712/1712 [==============================] - 1s 305us/step - loss: 1.1239e-04 - val_loss: 8.0799e-04
#
# Epoch 00093: val_loss did not improve from 0.00076
# Epoch 94/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 1.1149e-04 - val_loss: 7.9803e-04
#
# Epoch 00094: val_loss did not improve from 0.00076
# Epoch 95/150
# 1712/1712 [==============================] - 0s 287us/step - loss: 1.1252e-04 - val_loss: 8.1656e-04
#
# Epoch 00095: val_loss did not improve from 0.00076
# Epoch 96/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.1161e-04 - val_loss: 7.5472e-04
#
# Epoch 00096: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 97/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 1.1025e-04 - val_loss: 7.8847e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 0s 286us/step - loss: 1.0569e-04 - val_loss: 7.7609e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 1.0911e-04 - val_loss: 7.8907e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.1135e-04 - val_loss: 7.8550e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 1.1020e-04 - val_loss: 7.6594e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.1110e-04 - val_loss: 7.6675e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 1s 306us/step - loss: 1.0405e-04 - val_loss: 8.3400e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.0683e-04 - val_loss: 8.2287e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 1s 311us/step - loss: 1.0532e-04 - val_loss: 7.7524e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 1.0612e-04 - val_loss: 7.7396e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 1s 292us/step - loss: 1.0506e-04 - val_loss: 7.9978e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 1.0507e-04 - val_loss: 7.8708e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.0288e-04 - val_loss: 8.0419e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 1.0043e-04 - val_loss: 8.0976e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 1.0119e-04 - val_loss: 7.9677e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 1.0021e-04 - val_loss: 8.7818e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 1.0896e-04 - val_loss: 7.7312e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 1.0523e-04 - val_loss: 7.8468e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 9.9250e-05 - val_loss: 8.1934e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 9.8289e-05 - val_loss: 7.5849e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 9.8952e-05 - val_loss: 7.7316e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 9.7012e-05 - val_loss: 7.8650e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 9.4219e-05 - val_loss: 7.9963e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 1s 307us/step - loss: 9.4801e-05 - val_loss: 7.7238e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 9.0133e-05 - val_loss: 7.9420e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 1s 305us/step - loss: 9.5799e-05 - val_loss: 7.5929e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 1s 307us/step - loss: 9.1911e-05 - val_loss: 8.0381e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 1s 300us/step - loss: 9.2350e-05 - val_loss: 8.0051e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 9.3628e-05 - val_loss: 8.1216e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 9.1547e-05 - val_loss: 8.1944e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 9.1567e-05 - val_loss: 7.6437e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 1s 299us/step - loss: 8.9209e-05 - val_loss: 7.8516e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 0s 292us/step - loss: 9.2598e-05 - val_loss: 7.5577e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 8.9540e-05 - val_loss: 8.0064e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 8.7862e-05 - val_loss: 7.8491e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 1s 310us/step - loss: 8.8196e-05 - val_loss: 7.9261e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 1s 302us/step - loss: 8.5418e-05 - val_loss: 8.2997e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 8.8147e-05 - val_loss: 8.1070e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 0s 291us/step - loss: 8.7336e-05 - val_loss: 7.8109e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 8.5247e-05 - val_loss: 7.6861e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 8.6651e-05 - val_loss: 8.0771e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 8.5515e-05 - val_loss: 8.0624e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 8.5558e-05 - val_loss: 7.7870e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 1s 298us/step - loss: 8.6889e-05 - val_loss: 7.8304e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 1s 293us/step - loss: 8.6636e-05 - val_loss: 7.9109e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 1s 303us/step - loss: 8.6563e-05 - val_loss: 7.8189e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 1s 294us/step - loss: 8.4316e-05 - val_loss: 7.9536e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 8.2828e-05 - val_loss: 8.1529e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 1s 297us/step - loss: 8.3051e-05 - val_loss: 8.1440e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 1s 306us/step - loss: 8.2698e-05 - val_loss: 7.8923e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 8.3138e-05 - val_loss: 8.4001e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 1s 296us/step - loss: 8.1053e-05 - val_loss: 7.8105e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 1s 295us/step - loss: 7.9697e-05 - val_loss: 8.0569e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 1s 306us/step - loss: 7.9574e-05 - val_loss: 7.8671e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 418us/step - loss: 0.0060 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00208, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00208 to 0.00195, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00188, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00182, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 8.7407e-04 - val_loss: 0.0016
#
# Epoch 00005: val_loss improved from 0.00182 to 0.00156, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 301us/step - loss: 7.1487e-04 - val_loss: 0.0014
#
# Epoch 00006: val_loss improved from 0.00156 to 0.00135, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 306us/step - loss: 6.1512e-04 - val_loss: 0.0012
#
# Epoch 00007: val_loss improved from 0.00135 to 0.00115, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 5.3837e-04 - val_loss: 0.0010
#
# Epoch 00008: val_loss improved from 0.00115 to 0.00104, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 4.8262e-04 - val_loss: 0.0010
#
# Epoch 00009: val_loss did not improve from 0.00104
# Epoch 10/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 4.3947e-04 - val_loss: 9.2646e-04
#
# Epoch 00010: val_loss improved from 0.00104 to 0.00093, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 301us/step - loss: 4.0973e-04 - val_loss: 9.0511e-04
#
# Epoch 00011: val_loss improved from 0.00093 to 0.00091, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 3.8643e-04 - val_loss: 8.4242e-04
#
# Epoch 00012: val_loss improved from 0.00091 to 0.00084, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 3.6271e-04 - val_loss: 7.9665e-04
#
# Epoch 00013: val_loss improved from 0.00084 to 0.00080, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 3.3200e-04 - val_loss: 7.7857e-04
#
# Epoch 00014: val_loss improved from 0.00080 to 0.00078, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 3.2732e-04 - val_loss: 8.2365e-04
#
# Epoch 00015: val_loss did not improve from 0.00078
# Epoch 16/150
# 3424/3424 [==============================] - 1s 301us/step - loss: 3.0538e-04 - val_loss: 7.3280e-04
#
# Epoch 00016: val_loss improved from 0.00078 to 0.00073, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.9022e-04 - val_loss: 7.1063e-04
#
# Epoch 00017: val_loss improved from 0.00073 to 0.00071, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 2.8586e-04 - val_loss: 7.2018e-04
#
# Epoch 00018: val_loss did not improve from 0.00071
# Epoch 19/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.7747e-04 - val_loss: 7.1695e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.6161e-04 - val_loss: 7.1893e-04
#
# Epoch 00020: val_loss did not improve from 0.00071
# Epoch 21/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 2.5804e-04 - val_loss: 6.7040e-04
#
# Epoch 00021: val_loss improved from 0.00071 to 0.00067, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 2.5141e-04 - val_loss: 7.3289e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 2.4724e-04 - val_loss: 6.7751e-04
#
# Epoch 00023: val_loss did not improve from 0.00067
# Epoch 24/150
# 3424/3424 [==============================] - 1s 306us/step - loss: 2.4059e-04 - val_loss: 6.6617e-04
#
# Epoch 00024: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.3500e-04 - val_loss: 7.2309e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.2713e-04 - val_loss: 6.7006e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 2.2426e-04 - val_loss: 6.6233e-04
#
# Epoch 00027: val_loss improved from 0.00067 to 0.00066, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 2.1746e-04 - val_loss: 6.4796e-04
#
# Epoch 00028: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.1377e-04 - val_loss: 6.7698e-04
#
# Epoch 00029: val_loss did not improve from 0.00065
# Epoch 30/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 2.0689e-04 - val_loss: 6.6277e-04
#
# Epoch 00030: val_loss did not improve from 0.00065
# Epoch 31/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 1.9995e-04 - val_loss: 6.5298e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.9569e-04 - val_loss: 6.4206e-04
#
# Epoch 00032: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.9183e-04 - val_loss: 6.4200e-04
#
# Epoch 00033: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 34/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 1.8980e-04 - val_loss: 6.4959e-04
#
# Epoch 00034: val_loss did not improve from 0.00064
# Epoch 35/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 1.8436e-04 - val_loss: 6.0282e-04
#
# Epoch 00035: val_loss improved from 0.00064 to 0.00060, saving model to best_weights_augment.h5
# Epoch 36/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 1.8352e-04 - val_loss: 6.2394e-04
#
# Epoch 00036: val_loss did not improve from 0.00060
# Epoch 37/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.8120e-04 - val_loss: 6.2936e-04
#
# Epoch 00037: val_loss did not improve from 0.00060
# Epoch 38/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.7712e-04 - val_loss: 6.0677e-04
#
# Epoch 00038: val_loss did not improve from 0.00060
# Epoch 39/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.7253e-04 - val_loss: 6.1479e-04
#
# Epoch 00039: val_loss did not improve from 0.00060
# Epoch 40/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 1.7103e-04 - val_loss: 6.5923e-04
#
# Epoch 00040: val_loss did not improve from 0.00060
# Epoch 41/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 1.6679e-04 - val_loss: 6.1958e-04
#
# Epoch 00041: val_loss did not improve from 0.00060
# Epoch 42/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 1.6138e-04 - val_loss: 6.6217e-04
#
# Epoch 00042: val_loss did not improve from 0.00060
# Epoch 43/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.6401e-04 - val_loss: 5.9291e-04
#
# Epoch 00043: val_loss improved from 0.00060 to 0.00059, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.6180e-04 - val_loss: 6.1463e-04
#
# Epoch 00044: val_loss did not improve from 0.00059
# Epoch 45/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.5859e-04 - val_loss: 6.2041e-04
#
# Epoch 00045: val_loss did not improve from 0.00059
# Epoch 46/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.5680e-04 - val_loss: 6.2383e-04
#
# Epoch 00046: val_loss did not improve from 0.00059
# Epoch 47/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.5474e-04 - val_loss: 6.0146e-04
#
# Epoch 00047: val_loss did not improve from 0.00059
# Epoch 48/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.5328e-04 - val_loss: 6.3357e-04
#
# Epoch 00048: val_loss did not improve from 0.00059
# Epoch 49/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 1.4947e-04 - val_loss: 6.2045e-04
#
# Epoch 00049: val_loss did not improve from 0.00059
# Epoch 50/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 1.5004e-04 - val_loss: 6.5827e-04
#
# Epoch 00050: val_loss did not improve from 0.00059
# Epoch 51/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.4607e-04 - val_loss: 6.0877e-04
#
# Epoch 00051: val_loss did not improve from 0.00059
# Epoch 52/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.4375e-04 - val_loss: 6.6443e-04
#
# Epoch 00052: val_loss did not improve from 0.00059
# Epoch 53/150
# 3424/3424 [==============================] - 1s 304us/step - loss: 1.4611e-04 - val_loss: 5.8574e-04
#
# Epoch 00053: val_loss improved from 0.00059 to 0.00059, saving model to best_weights_augment.h5
# Epoch 54/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.4334e-04 - val_loss: 6.3218e-04
#
# Epoch 00054: val_loss did not improve from 0.00059
# Epoch 55/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.3953e-04 - val_loss: 6.0926e-04
#
# Epoch 00055: val_loss did not improve from 0.00059
# Epoch 56/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.3769e-04 - val_loss: 6.0988e-04
#
# Epoch 00056: val_loss did not improve from 0.00059
# Epoch 57/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.3391e-04 - val_loss: 6.0072e-04
#
# Epoch 00057: val_loss did not improve from 0.00059
# Epoch 58/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.3601e-04 - val_loss: 6.0766e-04
#
# Epoch 00058: val_loss did not improve from 0.00059
# Epoch 59/150
# 3424/3424 [==============================] - 1s 290us/step - loss: 1.3238e-04 - val_loss: 5.9958e-04
#
# Epoch 00059: val_loss did not improve from 0.00059
# Epoch 60/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.3291e-04 - val_loss: 6.4495e-04
#
# Epoch 00060: val_loss did not improve from 0.00059
# Epoch 61/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.3179e-04 - val_loss: 6.5837e-04
#
# Epoch 00061: val_loss did not improve from 0.00059
# Epoch 62/150
# 3424/3424 [==============================] - 1s 301us/step - loss: 1.2995e-04 - val_loss: 6.0159e-04
#
# Epoch 00062: val_loss did not improve from 0.00059
# Epoch 63/150
# 3424/3424 [==============================] - 1s 307us/step - loss: 1.3060e-04 - val_loss: 6.0522e-04
#
# Epoch 00063: val_loss did not improve from 0.00059
# Epoch 64/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.2529e-04 - val_loss: 6.0132e-04
#
# Epoch 00064: val_loss did not improve from 0.00059
# Epoch 65/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 1.2576e-04 - val_loss: 5.9720e-04
#
# Epoch 00065: val_loss did not improve from 0.00059
# Epoch 66/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 1.2446e-04 - val_loss: 6.0221e-04
#
# Epoch 00066: val_loss did not improve from 0.00059
# Epoch 67/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 1.2467e-04 - val_loss: 6.4380e-04
#
# Epoch 00067: val_loss did not improve from 0.00059
# Epoch 68/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.2212e-04 - val_loss: 6.1452e-04
#
# Epoch 00068: val_loss did not improve from 0.00059
# Epoch 69/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.1838e-04 - val_loss: 6.0464e-04
#
# Epoch 00069: val_loss did not improve from 0.00059
# Epoch 70/150
# 3424/3424 [==============================] - 1s 307us/step - loss: 1.2058e-04 - val_loss: 6.1570e-04
#
# Epoch 00070: val_loss did not improve from 0.00059
# Epoch 71/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 1.1930e-04 - val_loss: 5.7761e-04
#
# Epoch 00071: val_loss improved from 0.00059 to 0.00058, saving model to best_weights_augment.h5
# Epoch 72/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.1371e-04 - val_loss: 5.9656e-04
#
# Epoch 00072: val_loss did not improve from 0.00058
# Epoch 73/150
# 3424/3424 [==============================] - 1s 312us/step - loss: 1.1643e-04 - val_loss: 6.0569e-04
#
# Epoch 00073: val_loss did not improve from 0.00058
# Epoch 74/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.1574e-04 - val_loss: 6.2519e-04
#
# Epoch 00074: val_loss did not improve from 0.00058
# Epoch 75/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 1.1203e-04 - val_loss: 6.1082e-04
#
# Epoch 00075: val_loss did not improve from 0.00058
# Epoch 76/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 1.1431e-04 - val_loss: 6.1079e-04
#
# Epoch 00076: val_loss did not improve from 0.00058
# Epoch 77/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 1.1166e-04 - val_loss: 6.3081e-04
#
# Epoch 00077: val_loss did not improve from 0.00058
# Epoch 78/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 1.1158e-04 - val_loss: 5.9075e-04
#
# Epoch 00078: val_loss did not improve from 0.00058
# Epoch 79/150
# 3424/3424 [==============================] - 1s 289us/step - loss: 1.1092e-04 - val_loss: 5.8603e-04
#
# Epoch 00079: val_loss did not improve from 0.00058
# Epoch 80/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.1057e-04 - val_loss: 6.2086e-04
#
# Epoch 00080: val_loss did not improve from 0.00058
# Epoch 81/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.0800e-04 - val_loss: 6.0807e-04
#
# Epoch 00081: val_loss did not improve from 0.00058
# Epoch 82/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 1.0825e-04 - val_loss: 6.1489e-04
#
# Epoch 00082: val_loss did not improve from 0.00058
# Epoch 83/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.0616e-04 - val_loss: 5.8711e-04
#
# Epoch 00083: val_loss did not improve from 0.00058
# Epoch 84/150
# 3424/3424 [==============================] - 1s 290us/step - loss: 1.0530e-04 - val_loss: 6.2196e-04
#
# Epoch 00084: val_loss did not improve from 0.00058
# Epoch 85/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 1.0368e-04 - val_loss: 6.0182e-04
#
# Epoch 00085: val_loss did not improve from 0.00058
# Epoch 86/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 1.0826e-04 - val_loss: 6.0647e-04
#
# Epoch 00086: val_loss did not improve from 0.00058
# Epoch 87/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 1.0326e-04 - val_loss: 5.8733e-04
#
# Epoch 00087: val_loss did not improve from 0.00058
# Epoch 88/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 1.0167e-04 - val_loss: 6.3227e-04
#
# Epoch 00088: val_loss did not improve from 0.00058
# Epoch 89/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 1.0410e-04 - val_loss: 6.3072e-04
#
# Epoch 00089: val_loss did not improve from 0.00058
# Epoch 90/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 1.0355e-04 - val_loss: 6.7033e-04
#
# Epoch 00090: val_loss did not improve from 0.00058
# Epoch 91/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 1.0077e-04 - val_loss: 6.1043e-04
#
# Epoch 00091: val_loss did not improve from 0.00058
# Epoch 92/150
# 3424/3424 [==============================] - 1s 301us/step - loss: 1.0044e-04 - val_loss: 6.1435e-04
#
# Epoch 00092: val_loss did not improve from 0.00058
# Epoch 93/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 1.0131e-04 - val_loss: 6.0634e-04
#
# Epoch 00093: val_loss did not improve from 0.00058
# Epoch 94/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 9.9651e-05 - val_loss: 5.9005e-04
#
# Epoch 00094: val_loss did not improve from 0.00058
# Epoch 95/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 9.7679e-05 - val_loss: 6.0954e-04
#
# Epoch 00095: val_loss did not improve from 0.00058
# Epoch 96/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 9.6066e-05 - val_loss: 6.1218e-04
#
# Epoch 00096: val_loss did not improve from 0.00058
# Epoch 97/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 9.7638e-05 - val_loss: 6.0395e-04
#
# Epoch 00097: val_loss did not improve from 0.00058
# Epoch 98/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 9.4879e-05 - val_loss: 5.9142e-04
#
# Epoch 00098: val_loss did not improve from 0.00058
# Epoch 99/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 9.5419e-05 - val_loss: 5.9856e-04
#
# Epoch 00099: val_loss did not improve from 0.00058
# Epoch 100/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 9.5945e-05 - val_loss: 6.1288e-04
#
# Epoch 00100: val_loss did not improve from 0.00058
# Epoch 101/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 9.4498e-05 - val_loss: 6.2311e-04
#
# Epoch 00101: val_loss did not improve from 0.00058
# Epoch 102/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 9.7950e-05 - val_loss: 5.9087e-04
#
# Epoch 00102: val_loss did not improve from 0.00058
# Epoch 103/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 9.6247e-05 - val_loss: 5.8554e-04
#
# Epoch 00103: val_loss did not improve from 0.00058
# Epoch 104/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 9.3293e-05 - val_loss: 5.8895e-04
#
# Epoch 00104: val_loss did not improve from 0.00058
# Epoch 105/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 9.2224e-05 - val_loss: 6.0592e-04
#
# Epoch 00105: val_loss did not improve from 0.00058
# Epoch 106/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 9.4036e-05 - val_loss: 5.9631e-04
#
# Epoch 00106: val_loss did not improve from 0.00058
# Epoch 107/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 9.2827e-05 - val_loss: 6.2103e-04
#
# Epoch 00107: val_loss did not improve from 0.00058
# Epoch 108/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 9.2188e-05 - val_loss: 5.9385e-04
#
# Epoch 00108: val_loss did not improve from 0.00058
# Epoch 109/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 9.3565e-05 - val_loss: 5.9838e-04
#
# Epoch 00109: val_loss did not improve from 0.00058
# Epoch 110/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 9.2817e-05 - val_loss: 6.1347e-04
#
# Epoch 00110: val_loss did not improve from 0.00058
# Epoch 111/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 9.1238e-05 - val_loss: 5.9186e-04
#
# Epoch 00111: val_loss did not improve from 0.00058
# Epoch 112/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 9.1132e-05 - val_loss: 6.1811e-04
#
# Epoch 00112: val_loss did not improve from 0.00058
# Epoch 113/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 9.1931e-05 - val_loss: 6.1986e-04
#
# Epoch 00113: val_loss did not improve from 0.00058
# Epoch 114/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 8.8825e-05 - val_loss: 6.1423e-04
#
# Epoch 00114: val_loss did not improve from 0.00058
# Epoch 115/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 8.9620e-05 - val_loss: 6.0975e-04
#
# Epoch 00115: val_loss did not improve from 0.00058
# Epoch 116/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 9.1259e-05 - val_loss: 5.8164e-04
#
# Epoch 00116: val_loss did not improve from 0.00058
# Epoch 117/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 8.9794e-05 - val_loss: 6.2644e-04
#
# Epoch 00117: val_loss did not improve from 0.00058
# Epoch 118/150
# 3424/3424 [==============================] - 1s 306us/step - loss: 8.9331e-05 - val_loss: 5.7860e-04
#
# Epoch 00118: val_loss did not improve from 0.00058
# Epoch 119/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 8.8086e-05 - val_loss: 5.8992e-04
#
# Epoch 00119: val_loss did not improve from 0.00058
# Epoch 120/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 8.7819e-05 - val_loss: 5.9346e-04
#
# Epoch 00120: val_loss did not improve from 0.00058
# Epoch 121/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 8.7760e-05 - val_loss: 5.9312e-04
#
# Epoch 00121: val_loss did not improve from 0.00058
# Epoch 122/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 8.6852e-05 - val_loss: 6.1690e-04
#
# Epoch 00122: val_loss did not improve from 0.00058
# Epoch 123/150
# 3424/3424 [==============================] - 1s 291us/step - loss: 8.4687e-05 - val_loss: 6.1419e-04
#
# Epoch 00123: val_loss did not improve from 0.00058
# Epoch 124/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 8.7999e-05 - val_loss: 6.2575e-04
#
# Epoch 00124: val_loss did not improve from 0.00058
# Epoch 125/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 8.8504e-05 - val_loss: 6.1795e-04
#
# Epoch 00125: val_loss did not improve from 0.00058
# Epoch 126/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 8.7908e-05 - val_loss: 6.1694e-04
#
# Epoch 00126: val_loss did not improve from 0.00058
# Epoch 127/150
# 3424/3424 [==============================] - 1s 298us/step - loss: 8.7498e-05 - val_loss: 6.1117e-04
#
# Epoch 00127: val_loss did not improve from 0.00058
# Epoch 128/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 9.1976e-05 - val_loss: 6.2553e-04
#
# Epoch 00128: val_loss did not improve from 0.00058
# Epoch 129/150
# 3424/3424 [==============================] - 1s 306us/step - loss: 8.8138e-05 - val_loss: 6.2790e-04
#
# Epoch 00129: val_loss did not improve from 0.00058
# Epoch 130/150
# 3424/3424 [==============================] - 1s 299us/step - loss: 8.7122e-05 - val_loss: 6.3441e-04
#
# Epoch 00130: val_loss did not improve from 0.00058
# Epoch 131/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 8.6698e-05 - val_loss: 5.9689e-04
#
# Epoch 00131: val_loss did not improve from 0.00058
# Epoch 132/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 8.5469e-05 - val_loss: 5.7899e-04
#
# Epoch 00132: val_loss did not improve from 0.00058
# Epoch 133/150
# 3424/3424 [==============================] - 1s 306us/step - loss: 8.4093e-05 - val_loss: 6.0795e-04
#
# Epoch 00133: val_loss did not improve from 0.00058
# Epoch 134/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 8.4483e-05 - val_loss: 5.9970e-04
#
# Epoch 00134: val_loss did not improve from 0.00058
# Epoch 135/150
# 3424/3424 [==============================] - 1s 297us/step - loss: 8.5825e-05 - val_loss: 6.0298e-04
#
# Epoch 00135: val_loss did not improve from 0.00058
# Epoch 136/150
# 3424/3424 [==============================] - 1s 308us/step - loss: 8.3066e-05 - val_loss: 5.9642e-04
#
# Epoch 00136: val_loss did not improve from 0.00058
# Epoch 137/150
# 3424/3424 [==============================] - 1s 302us/step - loss: 8.2327e-05 - val_loss: 6.0106e-04
#
# Epoch 00137: val_loss did not improve from 0.00058
# Epoch 138/150
# 3424/3424 [==============================] - 1s 296us/step - loss: 8.1162e-05 - val_loss: 6.1691e-04
#
# Epoch 00138: val_loss did not improve from 0.00058
# Epoch 139/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 8.2714e-05 - val_loss: 5.8891e-04
#
# Epoch 00139: val_loss did not improve from 0.00058
# Epoch 140/150
# 3424/3424 [==============================] - 1s 304us/step - loss: 8.3629e-05 - val_loss: 6.1360e-04
#
# Epoch 00140: val_loss did not improve from 0.00058
# Epoch 141/150
# 3424/3424 [==============================] - 1s 300us/step - loss: 8.0973e-05 - val_loss: 6.1167e-04
#
# Epoch 00141: val_loss did not improve from 0.00058
# Epoch 142/150
# 3424/3424 [==============================] - 1s 294us/step - loss: 8.6337e-05 - val_loss: 6.1658e-04
#
# Epoch 00142: val_loss did not improve from 0.00058
# Epoch 143/150
# 3424/3424 [==============================] - 1s 289us/step - loss: 8.1758e-05 - val_loss: 6.0478e-04
#
# Epoch 00143: val_loss did not improve from 0.00058
# Epoch 144/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 8.1808e-05 - val_loss: 6.1964e-04
#
# Epoch 00144: val_loss did not improve from 0.00058
# Epoch 145/150
# 3424/3424 [==============================] - 1s 303us/step - loss: 8.2594e-05 - val_loss: 6.1378e-04
#
# Epoch 00145: val_loss did not improve from 0.00058
# Epoch 146/150
# 3424/3424 [==============================] - 1s 293us/step - loss: 8.2866e-05 - val_loss: 6.0545e-04
#
# Epoch 00146: val_loss did not improve from 0.00058
# Epoch 147/150
# 3424/3424 [==============================] - 1s 292us/step - loss: 8.0813e-05 - val_loss: 6.0351e-04
#
# Epoch 00147: val_loss did not improve from 0.00058
# Epoch 148/150
# 3424/3424 [==============================] - 1s 290us/step - loss: 8.1243e-05 - val_loss: 6.0477e-04
#
# Epoch 00148: val_loss did not improve from 0.00058
# Epoch 149/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 8.1338e-05 - val_loss: 6.0069e-04
#
# Epoch 00149: val_loss did not improve from 0.00058
# Epoch 150/150
# 3424/3424 [==============================] - 1s 295us/step - loss: 8.1532e-05 - val_loss: 5.9798e-04
#
# Epoch 00150: val_loss did not improve from 0.00058

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
